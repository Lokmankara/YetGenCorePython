# %% [markdown]
# # Problem 1
# Bir sayının çift olup olmadığını sorgulayan bir fonksiyon yazın. Bu fonksiyon, eğer sayı çift ise bu değeri dönsün. Ancak sayı tek sayı ise fonksiyon raise ile ValueError hatası oluştursun. Daha sonra, içinde çift ve tek sayılar bulunduran bir liste tanımlayın ve liste üzerinde gezinerek ekrana sadece çift sayıları bastırın.

# %%
def ciftMi(sayilar):
    for i in sayilar:
        if i %2 == 0: 
            print(i)
        else:
            raise ValueError("Girilen sayıların içerisinde tek sayı var!")

Listem = [1,2,3,4,5]
ciftMi(Listem)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 9
#       6             raise ValueError("Girilen sayıların içerisinde tek sayı var!")
#       8 Listem = [1,2,3,4,5]
# ----> 9 ciftMi(Listem)
#
# Cell In[1], line 6, in ciftMi(sayilar)
#       4     print(i)
#       5 else:
# ----> 6     raise ValueError("Girilen sayıların içerisinde tek sayı var!")
#
# ValueError: Girilen sayıların içerisinde tek sayı var!

# %%
def ciftMi(sayilar):
    for i in sayilar:
        if i %2 == 0: 
            print(i)
        else:
            raise ValueError("Girilen sayıların içerisinde tek sayı var!")

Listem = [2,4,6,8]
ciftMi(Listem)
# Out:
# 2
# 4
# 6
# 8

# %%
#LİDERİMİN EKSTRA ÖRNEĞİ: Türkçe karakter olursa value error hatası versin. 

turkce = ["ü","ö","ş","ğ","ı"]
isim = input("Lütfen isminizi giriniz...")
for harf in isim:
    if harf in turkce:
        raise ValueError("Lütfen Türkçe karakter kullanmayınız! ")
    
print(isim)
# Out:
# lokman

# %% [markdown]
# # Problem 2
#
# 2 YetGen lideri ders sırasında canları sıkılınca oyun oynamak isterler. Ancak hangi oyunu oynayacaklarına karar veremezler ve son olarak kendi oyunlarını yazmaya karar verirler.
# Liderlerimizin kodlamak istediği oyun kuralları şöyledir:
# - Oyunda random olarak 0 ile 100 arasında bir sayı tutulur.
# - Kullanıcıdan bilgisayarın tuttuğu sayıyı tahmin etmesi için bir sayı girmesini istenir.
# - Eğer kullanıcının girdiği sayı bulunması gereken sayıdan küçükse  tahmininizi yükseltin, büyükse tahmininizi düşürün şeklinde bir çıktı verilir.
# - Oyunun gerçeğe yakın olması için bilgisayarın çalışmasını simgelemek için 1 saniye bekleme süresi tanınır.
# - Kullanıcı 5 hakkı vardır. 5 hakkı da kullanıp sayıyı bulamazsa oyunu kaybeder.

# %%
# Random sayı yazmak için bir araç lazım, onu araştır. Range fonksiyonu düşündüm ama range random değil sırayla gidiyor dikkat et.  
# input ile bir sayı girişi isteyebiliriz. 
# 1 saniye bekleme süresi için bir kutuphane lazım, onu araştır. 
# Kullanıcının girdiği sayı kucukse daha buyuk sayı giriniz yazacak. Büyükse tam tersi yazacak. 
# Her kullanıcının 5 hakkı olacak ona göre bir sınır belirlemek lazım. 

## "random" diye kutuphane rastgele sayı veriyormuş. 
## "time" diye bir kutuphanede girdigin sayı kadar kodun çalışmasını durduryormuş. 

### Bir kutuphaneyi eklerken
